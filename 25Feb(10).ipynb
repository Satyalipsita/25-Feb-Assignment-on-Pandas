# %%
import pandas as pd
import matplotlib as mp
df=pd.read_csv("amazonsales.csv")

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df[["Total Cost","Total Revenue"]]
# Out:
#     Total Cost  Total Revenue
# 0   1582243.50     2533654.00
# 1    328376.44      576782.80
# 2    933903.84     1158502.59
# 3     56065.84       75591.66
# 4   2657347.52     3296425.02
# ..         ...            ...
# 95    31825.92       97040.64
# 96    43367.64       58471.11
# 97   135031.05      228779.10
# 98   326815.89      471336.91
# 99  2697132.18     3586605.09
#
# [100 rows x 2 columns]

# %%
df.plot.bar(x="Total Cost",y="Total Revenue")
# Out:
# <AxesSubplot:xlabel='Total Cost'>
